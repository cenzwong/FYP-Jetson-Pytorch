# %% [markdown]
# # Code to modify the model with feeding back from KMean

# %% [markdown]
# This load the model and replace the fully connected layer and saved as the new model

# %%
np_PTH_Quantization = [[ 0.03061169,  0.01361432,  0.01361432,  0.01361432, -0.03568947,
        0.03061169,  0.03061169,  0.03061169,  0.01361432, -0.0210254 ,
       -0.00318789, -0.00318789,  0.01361432,  0.01361432,  0.01361432,
       -0.00318789, -0.0210254 , -0.03568947,  0.01361432, -0.00318789,
        0.03061169, -0.0210254 ,  0.01361432,  0.03061169, -0.0210254 ,
        0.01361432, -0.03568947, -0.00318789, -0.00318789, -0.03568947,
        0.01361432, -0.0210254 , -0.03568947,  0.03061169, -0.0210254 ,
       -0.00318789,  0.03061169,  0.03061169,  0.03061169,  0.01361432,
       -0.0210254 , -0.00318789, -0.00318789,  0.01361432, -0.03568947,
       -0.0210254 ,  0.03061169, -0.03568947, -0.00318789, -0.0210254 ,
       -0.0210254 , -0.03568947,  0.01361432,  0.01361432,  0.03061169,
       -0.0210254 , -0.03568947,  0.01361432, -0.00318789, -0.00318789,
       -0.00318789, -0.0210254 , -0.0210254 , -0.0210254 , -0.00318789,
        0.01361432, -0.00318789,  0.03061169,  0.01361432, -0.0210254 ,
        0.01361432,  0.01361432,  0.03061169,  0.01361432,  0.01361432,
       -0.00318789, -0.00318789,  0.01361432, -0.0210254 , -0.03568947,
       -0.0210254 , -0.00318789, -0.03568947,  0.03061169,  0.03061169,
        0.01361432,  0.01361432, -0.03568947,  0.03061169,  0.03061169,
       -0.0210254 , -0.00318789,  0.01361432,  0.01361432, -0.03568947,
       -0.0210254 , -0.0210254 ,  0.01361432,  0.03061169,  0.01361432,
       -0.03568947,  0.03061169, -0.00318789,  0.03061169,  0.03061169,
       -0.0210254 , -0.03568947,  0.01361432, -0.00318789,  0.01361432,
       -0.03568947, -0.00318789,  0.01361432,  0.03061169, -0.00318789,
       -0.00318789,  0.03061169, -0.0210254 , -0.0210254 ,  0.03061169,
        0.01361432,  0.03061169, -0.00318789,  0.03061169, -0.00318789,
        0.03061169,  0.01361432,  0.03061169,  0.03061169,  0.01361432,
        0.03061169, -0.00318789, -0.00318789,  0.01361432,  0.01361432,
       -0.00318789, -0.00318789,  0.03061169, -0.0210254 ,  0.01361432,
        0.03061169, -0.03568947, -0.00318789, -0.00318789,  0.03061169,
        0.03061169, -0.00318789, -0.00318789,  0.03061169, -0.0210254 ,
       -0.0210254 , -0.03568947,  0.03061169, -0.00318789,  0.01361432,
        0.03061169,  0.01361432,  0.03061169,  0.03061169,  0.01361432,
       -0.0210254 ,  0.03061169,  0.03061169,  0.03061169,  0.01361432,
       -0.00318789, -0.0210254 ,  0.01361432, -0.00318789,  0.01361432,
       -0.03568947,  0.01361432,  0.01361432, -0.0210254 , -0.0210254 ,
       -0.0210254 , -0.0210254 ,  0.03061169, -0.0210254 ,  0.03061169,
       -0.0210254 ,  0.03061169, -0.00318789, -0.03568947, -0.0210254 ,
       -0.00318789,  0.01361432,  0.01361432, -0.00318789, -0.00318789,
       -0.0210254 ,  0.03061169,  0.01361432, -0.0210254 ,  0.01361432,
       -0.00318789,  0.01361432, -0.03568947,  0.03061169, -0.00318789,
        0.01361432,  0.01361432, -0.0210254 ,  0.03061169,  0.03061169,
        0.02726713,  0.02726713, -0.03052342,  0.02726713,  0.02726713,
       -0.00492653,  0.00897398, -0.00492653, -0.01738913, -0.03052342,
        0.00897398,  0.00897398,  0.00897398,  0.00897398,  0.02726713,
       -0.01738913, -0.00492653, -0.03052342, -0.03052342, -0.01738913,
       -0.00492653,  0.00897398,  0.02726713,  0.00897398,  0.00897398,
       -0.00492653, -0.01738913,  0.02726713, -0.00492653,  0.00897398,
        0.00897398,  0.00897398,  0.00897398, -0.00492653, -0.00492653,
       -0.01738913, -0.00492653, -0.01738913, -0.00492653,  0.00897398,
       -0.01738913, -0.03052342, -0.01738913, -0.00492653,  0.02726713,
       -0.03052342, -0.00492653, -0.03052342, -0.00492653, -0.03052342,
       -0.03052342, -0.01738913, -0.00492653,  0.00897398,  0.02726713,
       -0.00492653, -0.01738913, -0.00492653, -0.01738913,  0.02726713,
        0.00897398, -0.03052342, -0.00492653,  0.00897398,  0.02726713,
       -0.00492653, -0.03052342, -0.00492653, -0.03052342, -0.00492653,
       -0.03052342, -0.03052342, -0.01738913,  0.00897398, -0.03052342,
        0.00897398, -0.01738913, -0.00492653, -0.03052342,  0.00897398,
        0.02726713, -0.01738913, -0.03052342, -0.00492653,  0.00897398,
       -0.01738913,  0.00897398, -0.00492653, -0.03052342,  0.00897398,
       -0.00492653,  0.02726713,  0.02726713,  0.00897398,  0.02726713,
        0.00897398, -0.03052342, -0.00492653, -0.03052342,  0.00897398,
       -0.03052342, -0.03052342, -0.01738913, -0.03052342,  0.00897398,
       -0.00492653,  0.02726713,  0.00897398, -0.01738913, -0.03052342,
       -0.00492653, -0.00492653,  0.00897398,  0.02726713, -0.03052342,
        0.00897398, -0.01738913,  0.00897398, -0.01738913,  0.00897398,
        0.00897398, -0.01738913, -0.00492653,  0.00897398,  0.02726713,
        0.00897398,  0.02726713,  0.02726713,  0.00897398, -0.03052342,
        0.02726713, -0.01738913, -0.00492653, -0.00492653, -0.00492653,
       -0.00492653, -0.00492653, -0.00492653, -0.01738913,  0.00897398,
        0.02726713, -0.03052342, -0.01738913, -0.00492653,  0.02726713,
       -0.00492653, -0.03052342, -0.03052342, -0.00492653, -0.00492653,
       -0.00492653,  0.00897398]]

# %%
import torch

cuda_device = torch.device('cuda:0')
torch.Tensor(np_PTH_Quantization).cuda()
# Out:
# tensor([[ 0.0306,  0.0136,  0.0136,  ..., -0.0032,  0.0136, -0.0357],
#         [ 0.0273, -0.0049, -0.0049,  ..., -0.0049, -0.0049,  0.0090]],
#        device='cuda:0')

# %%
# ## Run the model
model_state_dict = torch.load("./Final_TF_2.pth")
# model.load_state_dict(torch.load("./FingerTracking400.pth"))
model_state_dict['fc.weight']
# Out:
# tensor([[ 0.0384,  0.0169,  0.0293,  ...,  0.0386, -0.0111, -0.0275],
#         [ 0.0251, -0.0386,  0.0168,  ...,  0.0279,  0.0177,  0.0118]],
#        device='cuda:0')

# %%
model_state_dict['fc.weight'] = torch.Tensor(np_PTH_Quantization).cuda()

# %%
output_dim = 2

import torchvision
# RESNET 18
model = torchvision.models.resnet18(pretrained=True)
model.fc = torch.nn.Linear(512, output_dim)
model = model.to(cuda_device)

model.load_state_dict(model_state_dict)

# %%
torch.save(model.state_dict(), "./myPath.pth")
